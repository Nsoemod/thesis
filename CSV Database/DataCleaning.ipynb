# %% [markdown]
# Thesis meta-database cleaning

# %%
import pandas as pd
import glob
import os

# Path to the directory containing your CSV files
csv_directory = "Exported CSVs/Zotero exports"

# Use glob to get all CSV files in the directory
csv_files = glob.glob(os.path.join(csv_directory, "*.csv"))

# Initialize an empty list to store DataFrames
dfs = []

# Loop through each CSV file and append to the list
for csv_file in csv_files:
    # Read the CSV file
    df = pd.read_csv(csv_file)

    # Optional: Add a column indicating the source file
    file_name = os.path.basename(csv_file)
    df['source_file'] = file_name

    # Append to the list
    dfs.append(df)

    # Print status (optional)
    print(f"Loaded {file_name} with {len(df)} rows")

# Concatenate all DataFrames in the list
combined_df = pd.concat(dfs, ignore_index=True)

# Show the dimensions of the combined DataFrame
print(f"\nCombined DataFrame has {combined_df.shape[0]} rows and {combined_df.shape[1]} columns")

# Save the combined DataFrame to a new CSV file
combined_df.to_csv("combined_dataset.csv", index=False)
print("Combined data saved to combined_dataset.csv")
# Out:
# Loaded ACL.csv with 110 rows
# Loaded NeurIPS.csv with 459 rows
# Loaded CVPR.csv with 108 rows
#
# Combined DataFrame has 677 rows and 88 columns
# Combined data saved to combined_dataset.csv

# %%
combined_df.head()
# Out:
#         Key        Item Type  Publication Year  \
# 0  ZLSVM7UD  conferencePaper            2024.0
# 1  WBN4DR9E         preprint            2024.0
# 2  9XF59PKK  conferencePaper            2024.0
# 3  IVP948X3  conferencePaper            2024.0
# 4  9FJT7KT3  conferencePaper            2024.0
#
#                                               Author  \
# 0  Li, Haoran; Guo, Dadi; Li, Donghao; Fan, Wei; ...
# 1                 Hu, Yong; Meng, Fandong; Zhou, Jie
# 2  Poesina, Eduard; Caragea, Cornelia; Ionescu, Radu
# 3  Wang, Xiyao; Zhou, Yuhang; Liu, Xiaoyu; Lu, Ho...
# 4  Xia, Congying; Xing, Chen; Du, Jiangshu; Yang,...
#
#                                                Title  \
# 0  PrivLM-Bench: A Multi-level Privacy Evaluation...
# 1  CSCD-NS: a Chinese Spelling Check Dataset for ...
# 2  A Novel Cartography-Based Curriculum Learning ...
# 3  Mementos: A Comprehensive Benchmark for Multim...
# 4  FOFO: A Benchmark to Evaluate LLMs’ Format-Fol...
#
#                                    Publication Title  ISBN ISSN  \
# 0  Proceedings of the 62nd Annual Meeting of the ...   NaN  NaN
# 1                                                NaN   NaN  NaN
# 2  Proceedings of the 62nd Annual Meeting of the ...   NaN  NaN
# 3  Proceedings of the 62nd Annual Meeting of the ...   NaN  NaN
# 4  Proceedings of the 62nd Annual Meeting of the ...   NaN  NaN
#
#                             DOI                                        Url  \
# 0   10.18653/v1/2024.acl-long.4   https://aclanthology.org/2024.acl-long.4
# 1     10.48550/arXiv.2211.08788            http://arxiv.org/abs/2211.08788
# 2  10.18653/v1/2024.acl-long.15  https://aclanthology.org/2024.acl-long.15
# 3  10.18653/v1/2024.acl-long.25  https://aclanthology.org/2024.acl-long.25
# 4  10.18653/v1/2024.acl-long.40  https://aclanthology.org/2024.acl-long.40
#
#    ... Version System Code Code Number Section Session  Committee  History  \
# 0  ...     NaN    NaN  NaN         NaN     NaN     NaN        NaN      NaN
# 1  ...     NaN    NaN  NaN         NaN     NaN     NaN        NaN      NaN
# 2  ...     NaN    NaN  NaN         NaN     NaN     NaN        NaN      NaN
# 3  ...     NaN    NaN  NaN         NaN     NaN     NaN        NaN      NaN
# 4  ...     NaN    NaN  NaN         NaN     NaN     NaN        NaN      NaN
#
#    Legislative Body  source_file
# 0               NaN      ACL.csv
# 1               NaN      ACL.csv
# 2               NaN      ACL.csv
# 3               NaN      ACL.csv
# 4               NaN      ACL.csv
#
# [5 rows x 88 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 677 entries, 0 to 676
# Data columns (total 88 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Key                   677 non-null    object
#  1   Item Type             677 non-null    object
#  2   Publication Year      220 non-null    float64
#  3   Author                676 non-null    object
#  4   Title                 677 non-null    object
#  5   Publication Title     176 non-null    object
#  6   ISBN                  72 non-null     float64
#  7   ISSN                  2 non-null      object
#  8   DOI                   221 non-null    object
#  9   Url                   221 non-null    object
#  10  Abstract Note         569 non-null    object
#  11  Date                  220 non-null    object
#  12  Date Added            677 non-null    object
#  13  Date Modified         677 non-null    object
#  14  Access Date           221 non-null    object
#  15  Pages                 176 non-null    object
#  16  Num Pages             0 non-null      float64
#  17  Issue                 2 non-null      float64
#  18  Volume                2 non-null      float64
#  19  Number Of Volumes     0 non-null      float64
#  20  Journal Abbreviation  2 non-null      object
#  21  Short Title           177 non-null    object
#  22  Series                0 non-null      float64
#  23  Series Number         0 non-null      float64
#  24  Series Text           0 non-null      float64
#  25  Series Title          0 non-null      float64
#  26  Publisher             214 non-null    object
#  27  Place                 173 non-null    object
#  28  Language              671 non-null    object
#  29  Rights                79 non-null     object
#  30  Type                  0 non-null      float64
#  31  Archive               0 non-null      float64
#  32  Archive Location      0 non-null      float64
#  33  Library Catalog       677 non-null    object
#  34  Call Number           0 non-null      float64
#  35  Extra                 36 non-null     object
#  36  Notes                 0 non-null      float64
#  37  File Attachments      677 non-null    object
#  38  Link Attachments      0 non-null      float64
#  39  Manual Tags           0 non-null      float64
#  40  Automatic Tags        37 non-null     object
#  41  Editor                0 non-null      float64
#  42  Series Editor         0 non-null      float64
#  43  Translator            0 non-null      float64
#  44  Contributor           1 non-null      object
#  45  Attorney Agent        0 non-null      float64
#  46  Book Author           0 non-null      float64
#  47  Cast Member           0 non-null      float64
#  48  Commenter             0 non-null      float64
#  49  Composer              0 non-null      float64
#  50  Cosponsor             0 non-null      float64
#  51  Counsel               0 non-null      float64
#  52  Interviewer           0 non-null      float64
#  53  Producer              0 non-null      float64
#  54  Recipient             0 non-null      float64
#  55  Reviewed Author       0 non-null      float64
#  56  Scriptwriter          0 non-null      float64
#  57  Words By              0 non-null      float64
#  58  Guest                 0 non-null      float64
#  59  Number                34 non-null     object
#  60  Edition               0 non-null      float64
#  61  Running Time          0 non-null      float64
#  62  Scale                 0 non-null      float64
#  63  Medium                1 non-null      object
#  64  Artwork Size          0 non-null      float64
#  65  Filing Date           0 non-null      float64
#  66  Application Number    0 non-null      float64
#  67  Assignee              0 non-null      float64
#  68  Issuing Authority     0 non-null      float64
#  69  Country               0 non-null      float64
#  70  Meeting Name          0 non-null      float64
#  71  Conference Name       173 non-null    object
#  72  Court                 0 non-null      float64
#  73  References            0 non-null      float64
#  74  Reporter              0 non-null      float64
#  75  Legal Status          0 non-null      float64
#  76  Priority Numbers      0 non-null      float64
#  77  Programming Language  0 non-null      float64
#  78  Version               2 non-null      object
#  79  System                0 non-null      float64
#  80  Code                  0 non-null      float64
#  81  Code Number           0 non-null      float64
#  82  Section               0 non-null      float64
#  83  Session               0 non-null      float64
#  84  Committee             0 non-null      float64
#  85  History               0 non-null      float64
#  86  Legislative Body      0 non-null      float64
#  87  source_file           677 non-null    object
# dtypes: float64(58), object(30)
# memory usage: 465.6+ KB

# %%
combined_df.to_csv("combined_dataset_full_column.csv", index=False)

# %%
df_select_columns = combined_df[['Key', 'Item Type', 'Publication Year', 'Author', 'Title', 'Publication Title', 'DOI', 'Url', 'Abstract Note', 'Date', 'Conference Name', 'source_file']].copy()
df_select_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 677 entries, 0 to 676
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Key                677 non-null    object
#  1   Item Type          677 non-null    object
#  2   Publication Year   220 non-null    float64
#  3   Author             676 non-null    object
#  4   Title              677 non-null    object
#  5   Publication Title  176 non-null    object
#  6   DOI                221 non-null    object
#  7   Url                221 non-null    object
#  8   Abstract Note      569 non-null    object
#  9   Date               220 non-null    object
#  10  Conference Name    173 non-null    object
#  11  source_file        677 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 63.6+ KB

# %%
import numpy as np
df_select_columns['Field'] = np.nan
df_select_columns['Novel Database'] = np.nan
df_select_columns['Representativity Mentions'] = np.nan
df_select_columns['Similarity Mentions'] = np.nan
df_select_columns['Diversity Mentions'] = np.nan
df_select_columns['Notes'] = np.nan

df_select_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 677 entries, 0 to 676
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Key                        677 non-null    object
#  1   Item Type                  677 non-null    object
#  2   Publication Year           220 non-null    float64
#  3   Author                     676 non-null    object
#  4   Title                      677 non-null    object
#  5   Publication Title          176 non-null    object
#  6   DOI                        221 non-null    object
#  7   Url                        221 non-null    object
#  8   Abstract Note              569 non-null    object
#  9   Date                       220 non-null    object
#  10  Conference Name            173 non-null    object
#  11  source_file                677 non-null    object
#  12  Field                      0 non-null      float64
#  13  Novel Database             0 non-null      float64
#  14  Representativity Mentions  0 non-null      float64
#  15  Similarity Mentions        0 non-null      float64
#  16  Diversity Mentions         0 non-null      float64
#  17  Notes                      0 non-null      float64
# dtypes: float64(7), object(11)
# memory usage: 95.3+ KB

# %%
df_select_columns.rename(columns={'source_file': 'Source File',}, inplace=True)
df_select_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 677 entries, 0 to 676
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Key                        677 non-null    object
#  1   Item Type                  677 non-null    object
#  2   Publication Year           220 non-null    float64
#  3   Author                     676 non-null    object
#  4   Title                      677 non-null    object
#  5   Publication Title          176 non-null    object
#  6   DOI                        221 non-null    object
#  7   Url                        221 non-null    object
#  8   Abstract Note              569 non-null    object
#  9   Date                       220 non-null    object
#  10  Conference Name            173 non-null    object
#  11  Source File                677 non-null    object
#  12  Field                      0 non-null      float64
#  13  Novel Database             0 non-null      float64
#  14  Representativity Mentions  0 non-null      float64
#  15  Similarity Mentions        0 non-null      float64
#  16  Diversity Mentions         0 non-null      float64
#  17  Notes                      0 non-null      float64
# dtypes: float64(7), object(11)
# memory usage: 95.3+ KB

# %%
df_select_columns.to_csv("cleaned_dataset_v1.csv", index=False)

# %%
neurips_df = df_select_columns[df_select_columns['Source File'] == 'NeurIPS.csv']
print(f"Total NeurIPS articles: {len(neurips_df)}")
neurips_df.head()
# Out:
# Total NeurIPS articles: 459
#           Key       Item Type  Publication Year  \
# 110  IHBLLIBV         dataset            2025.0
# 111  58JV2V3K  journalArticle               NaN
# 112  VRL2G4I9  journalArticle               NaN
# 113  IZFMDATR  journalArticle               NaN
# 114  I249SJTS  journalArticle               NaN
#
#                                                 Author  \
# 110                                Hauser, Jakob Elias
# 111      Dong, Linfeng; Wang, Wei; Qiao, Yu; Sun, Xiao
# 112  Zhang, Hang; Sun, Jiawei; Chen, Renqi; Liu, We...
# 113  Luo, Jialin; Wang, Yuanzhi; Gu, Ziqi; Qiu, Yid...
# 114  Chen, Cheng; Zhu, Junchen; Luo, Xu; Shen, Heng...
#
#                                                  Title Publication Title  \
# 110                                           HiST-LLM               NaN
# 111  LucidAction: A Hierarchical and Multi-model Da...               NaN
# 112  Empowering and Assessing the Utility of Large ...               NaN
# 113  MMM-RS: A Multi-modal, Multi-GSD, Multi-scene ...               NaN
# 114  CoIN: A Benchmark of Continual Instruction Tun...               NaN
#
#                          DOI                                             Url  \
# 110  10.5281/ZENODO.14671247  https://zenodo.org/doi/10.5281/zenodo.14671247
# 111                      NaN                                             NaN
# 112                      NaN                                             NaN
# 113                      NaN                                             NaN
# 114                      NaN                                             NaN
#
#                                          Abstract Note        Date  \
# 110  Large Language Models (LLMs) have the potentia...  2025-01-16
# 111                                                NaN         NaN
# 112  Large language models (LLMs) have demonstrated...         NaN
# 113  Recently, the diffusion-based generative parad...         NaN
# 114  Instruction tuning demonstrates impressive per...         NaN
#
#     Conference Name  Source File  Field  Novel Database  \
# 110             NaN  NeurIPS.csv    NaN             NaN
# 111             NaN  NeurIPS.csv    NaN             NaN
# 112             NaN  NeurIPS.csv    NaN             NaN
# 113             NaN  NeurIPS.csv    NaN             NaN
# 114             NaN  NeurIPS.csv    NaN             NaN
#
#      Representativity Mentions  Similarity Mentions  Diversity Mentions  Notes
# 110                        NaN                  NaN                 NaN    NaN
# 111                        NaN                  NaN                 NaN    NaN
# 112                        NaN                  NaN                 NaN    NaN
# 113                        NaN                  NaN                 NaN    NaN
# 114                        NaN                  NaN                 NaN    NaN

# %%
if len(neurips_df) >= 50:
    random_neurips = neurips_df.sample(n=50, random_state=42)  # random_state for reproducibility
else:
    print(f"Warning: Only {len(neurips_df)} NeurIPS articles available. Selecting all of them.")
    random_neurips = neurips_df

random_neurips.to_csv("random_neurips_selection.csv", index=False)
