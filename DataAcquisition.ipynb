# %%
# using openreview-py requests tqdm pdfplumber

# %%
import openreview
import requests
import os
import re
import csv
import pdfplumber
from tqdm import tqdm

def clean_filename(name: str) -> str:
    # remove special characters
    name = re.sub(r'[<>:"/\\|?*]', '', name)
    name = re.sub(r'\s+', '_', name).strip('_')
    return name

def download_neurips_articles():
    try:
        # initialize openreview client
        client = openreview.api.OpenReviewClient(baseurl='https://api2.openreview.net')

        # set up constants
        ACCEPTED_VENUE_ID = 'NeurIPS.cc/2024/Datasets_and_Benchmarks_Track'
        OUTPUT_DIR = 'NeurIPS2024_Datasets_and_Benchmarks'
        METADATA_CSV_FILE = os.path.join(OUTPUT_DIR, 'metadata.csv')

        # make output directory
        os.makedirs(OUTPUT_DIR, exist_ok=True)

        # get all accepted articles
        print(f"Querying openreview for venue ID: {ACCEPTED_VENUE_ID}")
        notes_iterator = openreview.tools.iterget_notes(client, content={'venueid': ACCEPTED_VENUE_ID})

        #notes_iterator = openreview.tools.iterget_notes(client, content={'venueid': ACCEPTED_VENUE_ID})
        all_notes = list(notes_iterator)
        print(f"Total notes retrieved: {len(all_notes)}")

        if not all_notes:
            print("No accepted articles found")
            return

        # downloading pdfs and metadata, extracting fulltext to .csv
        all_metadata = []
        print(f"Downloading {len(all_notes)} articles to '{OUTPUT_DIR}'")

        for note in tqdm(all_notes):
            try:
                title = note.content['title']['value']
                pdf_url_relative = note.content['pdf']['value']

                pdf_url_full = f"https://openreview.net{pdf_url_relative}"
                pdf_filename = f"{clean_filename(title)}.pdf"
                pdf_path = os.path.join(OUTPUT_DIR, pdf_filename)

                # download pdf
                if not os.path.exists(pdf_path):
                    response = requests.get(pdf_url_full, stream=True)
                    response.raise_for_status()
                    with open(pdf_path, 'wb') as f:
                        for chunk in response.iter_content(chunk_size=8192):
                            f.write(chunk)

                # extract fulltext
                fulltext = ""
                try:
                    with pdfplumber.open(pdf_path) as pdf:
                        fulltext = "\n".join(page.extract_text() or "" for page in pdf.pages)
                except Exception as e:
                    tqdm.write(f"Error extracting fulltext from {pdf_path}: {e}")
                    fulltext = "Could not extract fulltext"

                # collect metadata
                article_metadata = {
                    'title': title,
                    'keywords': note.content.get('keywords', {}).get('value', []),
                    'openreview_url': f"https://openreview.net/forum?id={note.id}",
                    'pdf_filename': pdf_filename,
                    'fulltext': fulltext
                }
                all_metadata.append(article_metadata)

            except Exception as e:
                tqdm.write(f"Error processing article '{note.content.get('title', {}).get('value', 'Unknown')}': {e}")

        if not all_metadata:
            print("No metadata found")
            return

        # save metadata to .csv
        with open(METADATA_CSV_FILE, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=all_metadata[0].keys())
            writer.writeheader()
            writer.writerows(all_metadata)

        print(f"Metadata saved to '{METADATA_CSV_FILE}'")

    except Exception as e:
        print(f"Error processing articles: {e}")

if __name__ == '__main__':
    download_neurips_articles()
    print("Done")
# Out:
# Querying openreview for venue ID: NeurIPS.cc/2024/Datasets_and_Benchmarks_Track
# Total notes retrieved: 459
# Downloading 459 articles to 'NeurIPS2024_Datasets_and_Benchmarks'
#   1%|          | 3/459 [00:18<46:17,  6.09s/it]Cannot set gray stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
# Cannot set gray stroke color because /'P8' is an invalid float value
# Cannot set gray non-stroke color because /'P8' is an invalid float value
# Cannot set gray stroke color because /'P9' is an invalid float value
# Cannot set gray non-stroke color because /'P9' is an invalid float value
# Cannot set gray stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P13' is an invalid float value
# Cannot set gray stroke color because /'P14' is an invalid float value
# Cannot set gray non-stroke color because /'P14' is an invalid float value
# Cannot set gray stroke color because /'P15' is an invalid float value
# Cannot set gray non-stroke color because /'P15' is an invalid float value
# Cannot set gray stroke color because /'P16' is an invalid float value
# Cannot set gray non-stroke color because /'P16' is an invalid float value
#   2%|▏         | 8/459 [00:59<1:04:19,  8.56s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
#   5%|▍         | 22/459 [02:46<1:24:06, 11.55s/it]Cannot set gray stroke color because /'P6' is an invalid float value
# Cannot set gray non-stroke color because /'P6' is an invalid float value
# Cannot set gray stroke color because /'P8' is an invalid float value
# Cannot set gray non-stroke color because /'P8' is an invalid float value
# Cannot set gray stroke color because /'P11' is an invalid float value
# Cannot set gray non-stroke color because /'P11' is an invalid float value
# Cannot set gray stroke color because /'P12' is an invalid float value
# Cannot set gray non-stroke color because /'P12' is an invalid float value
# Cannot set gray stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P13' is an invalid float value
#   5%|▌         | 23/459 [02:57<1:23:03, 11.43s/it]Cannot set gray non-stroke color because /'P3533' is an invalid float value
# Cannot set gray non-stroke color because /'P3554' is an invalid float value
# Cannot set gray non-stroke color because /'P3575' is an invalid float value
# Cannot set gray non-stroke color because /'P3596' is an invalid float value
# Cannot set gray non-stroke color because /'P3617' is an invalid float value
# Cannot set gray non-stroke color because /'P3638' is an invalid float value
# Cannot set gray non-stroke color because /'P3659' is an invalid float value
# Cannot set gray non-stroke color because /'P3680' is an invalid float value
# Cannot set gray non-stroke color because /'P3701' is an invalid float value
# Cannot set gray non-stroke color because /'P3722' is an invalid float value
# Cannot set gray non-stroke color because /'P3743' is an invalid float value
# Cannot set gray non-stroke color because /'P3764' is an invalid float value
# Cannot set gray non-stroke color because /'P3785' is an invalid float value
# Cannot set gray non-stroke color because /'P3806' is an invalid float value
# Cannot set gray non-stroke color because /'P3827' is an invalid float value
# Cannot set gray non-stroke color because /'P3848' is an invalid float value
# Cannot set gray non-stroke color because /'P3869' is an invalid float value
# Cannot set gray non-stroke color because /'P3890' is an invalid float value
# Cannot set gray non-stroke color because /'P3911' is an invalid float value
# Cannot set gray non-stroke color because /'P3932' is an invalid float value
# Cannot set gray non-stroke color because /'P3953' is an invalid float value
# Cannot set gray non-stroke color because /'P3974' is an invalid float value
#   5%|▌         | 24/459 [03:01<1:06:45,  9.21s/it]Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
#   5%|▌         | 25/459 [03:07<58:50,  8.13s/it]  Cannot set gray non-stroke color because /'P0' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
#   6%|▋         | 29/459 [03:37<53:29,  7.46s/it]  Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
#   7%|▋         | 32/459 [04:11<1:15:34, 10.62s/it]Cannot set gray non-stroke color because /'PT45' is an invalid float value
# Cannot set gray non-stroke color because /'PT47' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT18' is an invalid float value
# Cannot set gray non-stroke color because /'PT25' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT10' is an invalid float value
# Cannot set gray non-stroke color because /'PT12' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
# Cannot set gray non-stroke color because /'PT14' is an invalid float value
# Cannot set gray non-stroke color because /'PT16' is an invalid float value
#   8%|▊         | 38/459 [06:07<3:37:38, 31.02s/it]Cannot set gray non-stroke color because /'P22' is an invalid float value
#   9%|▊         | 40/459 [06:26<2:22:10, 20.36s/it]Cannot set gray non-stroke color because /'Paint5' is an invalid float value
# Cannot set gray non-stroke color because /'Paint6' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H7' is an invalid float value
#  10%|█         | 46/459 [07:10<1:12:30, 10.53s/it]Cannot set gray stroke color because /'p46' is an invalid float value
# Cannot set gray stroke color because /'p51' is an invalid float value
# Cannot set gray stroke color because /'p56' is an invalid float value
# Cannot set gray stroke color because /'p61' is an invalid float value
# Cannot set gray stroke color because /'p66' is an invalid float value
# Cannot set gray stroke color because /'p71' is an invalid float value
# Cannot set gray stroke color because /'p76' is an invalid float value
# Cannot set gray stroke color because /'p81' is an invalid float value
# Cannot set gray stroke color because /'p86' is an invalid float value
# Cannot set gray stroke color because /'p91' is an invalid float value
# Cannot set gray stroke color because /'p96' is an invalid float value
# Cannot set gray stroke color because /'p101' is an invalid float value
# Cannot set gray stroke color because /'p106' is an invalid float value
# Cannot set gray stroke color because /'p111' is an invalid float value
# Cannot set gray stroke color because /'p116' is an invalid float value
# Cannot set gray stroke color because /'p121' is an invalid float value
# Cannot set gray stroke color because /'p126' is an invalid float value
# Cannot set gray stroke color because /'p133' is an invalid float value
# Cannot set gray stroke color because /'p138' is an invalid float value
# Cannot set gray stroke color because /'p145' is an invalid float value
# Cannot set gray stroke color because /'p150' is an invalid float value
# Cannot set gray stroke color because /'p155' is an invalid float value
# Cannot set gray stroke color because /'p160' is an invalid float value
# Cannot set gray stroke color because /'p165' is an invalid float value
# Cannot set gray stroke color because /'p170' is an invalid float value
# Cannot set gray stroke color because /'p175' is an invalid float value
# Cannot set gray stroke color because /'p180' is an invalid float value
# Cannot set gray stroke color because /'p185' is an invalid float value
# Cannot set gray stroke color because /'p190' is an invalid float value
# Cannot set gray stroke color because /'p195' is an invalid float value
# Cannot set gray stroke color because /'p200' is an invalid float value
#  11%|█         | 50/459 [08:02<1:10:50, 10.39s/it]Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
#  11%|█         | 51/459 [08:16<1:19:23, 11.68s/it]Cannot set gray stroke color because /'P7' is an invalid float value
# Cannot set gray non-stroke color because /'P7' is an invalid float value
#  11%|█▏        | 52/459 [08:22<1:08:06, 10.04s/it]Cannot set gray stroke color because /'P4' is an invalid float value
# Cannot set gray non-stroke color because /'P4' is an invalid float value
# Cannot set gray stroke color because /'P7' is an invalid float value
# Cannot set gray non-stroke color because /'P7' is an invalid float value
# Cannot set gray stroke color because /'P8' is an invalid float value
# Cannot set gray non-stroke color because /'P8' is an invalid float value
# Cannot set gray stroke color because /'P9' is an invalid float value
# Cannot set gray non-stroke color because /'P9' is an invalid float value
# Cannot set gray stroke color because /'P10' is an invalid float value
# Cannot set gray non-stroke color because /'P10' is an invalid float value
# Cannot set gray stroke color because /'P11' is an invalid float value
# Cannot set gray non-stroke color because /'P11' is an invalid float value
# Cannot set gray stroke color because /'P12' is an invalid float value
# Cannot set gray non-stroke color because /'P12' is an invalid float value
# Cannot set gray stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P13' is an invalid float value
# Cannot set gray stroke color because /'P14' is an invalid float value
# Cannot set gray non-stroke color because /'P14' is an invalid float value
# Cannot set gray stroke color because /'P15' is an invalid float value
# Cannot set gray non-stroke color because /'P15' is an invalid float value
# Cannot set gray stroke color because /'P16' is an invalid float value
# Cannot set gray non-stroke color because /'P16' is an invalid float value
# Cannot set gray stroke color because /'P12' is an invalid float value
# Cannot set gray non-stroke color because /'P12' is an invalid float value
# Cannot set gray stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P13' is an invalid float value
# Cannot set gray stroke color because /'P14' is an invalid float value
# Cannot set gray non-stroke color because /'P14' is an invalid float value
# Cannot set gray stroke color because /'P15' is an invalid float value
# Cannot set gray non-stroke color because /'P15' is an invalid float value
# Cannot set gray stroke color because /'P16' is an invalid float value
# Cannot set gray non-stroke color because /'P16' is an invalid float value
# Cannot set gray stroke color because /'P17' is an invalid float value
# Cannot set gray non-stroke color because /'P17' is an invalid float value
# Cannot set gray stroke color because /'P18' is an invalid float value
# Cannot set gray non-stroke color because /'P18' is an invalid float value
# Cannot set gray stroke color because /'P19' is an invalid float value
# Cannot set gray non-stroke color because /'P19' is an invalid float value
# Cannot set gray stroke color because /'P20' is an invalid float value
# Cannot set gray non-stroke color because /'P20' is an invalid float value
# Cannot set gray stroke color because /'P21' is an invalid float value
# Cannot set gray non-stroke color because /'P21' is an invalid float value
# Cannot set gray stroke color because /'P22' is an invalid float value
# Cannot set gray non-stroke color because /'P22' is an invalid float value
# Cannot set gray stroke color because /'P23' is an invalid float value
# Cannot set gray non-stroke color because /'P23' is an invalid float value
# Cannot set gray stroke color because /'P24' is an invalid float value
# Cannot set gray non-stroke color because /'P24' is an invalid float value
# Cannot set gray stroke color because /'P25' is an invalid float value
# Cannot set gray non-stroke color because /'P25' is an invalid float value
# Cannot set gray stroke color because /'P26' is an invalid float value
# Cannot set gray non-stroke color because /'P26' is an invalid float value
# Cannot set gray stroke color because /'P27' is an invalid float value
# Cannot set gray non-stroke color because /'P27' is an invalid float value
# Cannot set gray stroke color because /'P28' is an invalid float value
# Cannot set gray non-stroke color because /'P28' is an invalid float value
# Cannot set gray stroke color because /'P29' is an invalid float value
# Cannot set gray non-stroke color because /'P29' is an invalid float value
# Cannot set gray stroke color because /'P30' is an invalid float value
# Cannot set gray non-stroke color because /'P30' is an invalid float value
# Cannot set gray stroke color because /'P31' is an invalid float value
# Cannot set gray non-stroke color because /'P31' is an invalid float value
# Cannot set gray stroke color because /'P37' is an invalid float value
# Cannot set gray non-stroke color because /'P37' is an invalid float value
# Cannot set gray stroke color because /'P38' is an invalid float value
# Cannot set gray non-stroke color because /'P38' is an invalid float value
# Cannot set gray stroke color because /'P39' is an invalid float value
# Cannot set gray non-stroke color because /'P39' is an invalid float value
# Cannot set gray stroke color because /'P40' is an invalid float value
# Cannot set gray non-stroke color because /'P40' is an invalid float value
# Cannot set gray stroke color because /'P41' is an invalid float value
# Cannot set gray non-stroke color because /'P41' is an invalid float value
# Cannot set gray stroke color because /'P42' is an invalid float value
# Cannot set gray non-stroke color because /'P42' is an invalid float value
# Cannot set gray stroke color because /'P43' is an invalid float value
# Cannot set gray non-stroke color because /'P43' is an invalid float value
# Cannot set gray stroke color because /'P44' is an invalid float value
# Cannot set gray non-stroke color because /'P44' is an invalid float value
# Cannot set gray stroke color because /'P45' is an invalid float value
# Cannot set gray non-stroke color because /'P45' is an invalid float value
# Cannot set gray stroke color because /'P46' is an invalid float value
# Cannot set gray non-stroke color because /'P46' is an invalid float value
# Cannot set gray stroke color because /'P52' is an invalid float value
# Cannot set gray non-stroke color because /'P52' is an invalid float value
#  13%|█▎        | 61/459 [09:59<1:22:13, 12.40s/it]Cannot set gray stroke color because /'P10' is an invalid float value
# Cannot set gray non-stroke color because /'P10' is an invalid float value
# Cannot set gray stroke color because /'P12' is an invalid float value
# Cannot set gray non-stroke color because /'P12' is an invalid float value
#  15%|█▍        | 68/459 [11:06<1:01:03,  9.37s/it]Cannot set gray non-stroke color because /'P0' is an invalid float value
#  15%|█▌        | 69/459 [11:10<50:30,  7.77s/it]  Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
# Cannot set gray non-stroke color because /'P4' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
#  18%|█▊        | 83/459 [13:31<1:27:40, 13.99s/it]Cannot set gray non-stroke color because /'P2' is an invalid float value
#  19%|█▊        | 86/459 [13:51<55:41,  8.96s/it]  Cannot set gray non-stroke color because /'P51' is an invalid float value
# Cannot set gray non-stroke color because /'P57' is an invalid float value
# Cannot set gray non-stroke color because /'P33' is an invalid float value
# Cannot set gray non-stroke color because /'P39' is an invalid float value
#  21%|██▏       | 98/459 [15:34<1:14:27, 12.38s/it]Cannot set gray stroke color because /'P4' is an invalid float value
# Cannot set gray non-stroke color because /'P4' is an invalid float value
# Cannot set gray stroke color because /'P7' is an invalid float value
# Cannot set gray non-stroke color because /'P7' is an invalid float value
#  22%|██▏       | 102/459 [16:46<1:45:13, 17.68s/it]Cannot set gray stroke color because /'P17' is an invalid float value
# Cannot set gray non-stroke color because /'P17' is an invalid float value
#  24%|██▎       | 109/459 [18:40<1:08:13, 11.70s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
#  25%|██▍       | 114/459 [19:52<1:14:25, 12.94s/it]Cannot set gray non-stroke color because /'P0' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
#  29%|██▉       | 132/459 [22:36<46:10,  8.47s/it]  Cannot set gray stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
# Cannot set gray stroke color because /'P23' is an invalid float value
# Cannot set gray non-stroke color because /'P23' is an invalid float value
# Cannot set gray stroke color because /'P27' is an invalid float value
# Cannot set gray non-stroke color because /'P27' is an invalid float value
#  29%|██▉       | 134/459 [22:57<55:06, 10.17s/it]Cannot set gray stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
#  31%|███       | 141/459 [24:03<55:56, 10.55s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
#  31%|███       | 142/459 [24:14<56:21, 10.67s/it]Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
#  32%|███▏      | 145/459 [24:27<32:47,  6.27s/it]Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Cannot set gray stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
# Cannot set gray stroke color because /'P6' is an invalid float value
# Cannot set gray non-stroke color because /'P6' is an invalid float value
# Cannot set gray stroke color because /'P7' is an invalid float value
# Cannot set gray non-stroke color because /'P7' is an invalid float value
# Cannot set gray stroke color because /'P8' is an invalid float value
# Cannot set gray non-stroke color because /'P8' is an invalid float value
# Cannot set gray stroke color because /'P9' is an invalid float value
# Cannot set gray non-stroke color because /'P9' is an invalid float value
# Cannot set gray stroke color because /'P10' is an invalid float value
# Cannot set gray non-stroke color because /'P10' is an invalid float value
# Cannot set gray stroke color because /'P11' is an invalid float value
# Cannot set gray non-stroke color because /'P11' is an invalid float value
# Cannot set gray stroke color because /'P12' is an invalid float value
# Cannot set gray non-stroke color because /'P12' is an invalid float value
# Cannot set gray stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P13' is an invalid float value
# Cannot set gray stroke color because /'P14' is an invalid float value
# Cannot set gray non-stroke color because /'P14' is an invalid float value
# Cannot set gray stroke color because /'P15' is an invalid float value
# Cannot set gray non-stroke color because /'P15' is an invalid float value
# Cannot set gray stroke color because /'P16' is an invalid float value
# Cannot set gray non-stroke color because /'P16' is an invalid float value
# Cannot set gray stroke color because /'P18' is an invalid float value
# Cannot set gray non-stroke color because /'P18' is an invalid float value
# Cannot set gray stroke color because /'P19' is an invalid float value
# Cannot set gray non-stroke color because /'P19' is an invalid float value
# Cannot set gray stroke color because /'P20' is an invalid float value
# Cannot set gray non-stroke color because /'P20' is an invalid float value
# Cannot set gray stroke color because /'P21' is an invalid float value
# Cannot set gray non-stroke color because /'P21' is an invalid float value
# Cannot set gray stroke color because /'P22' is an invalid float value
# Cannot set gray non-stroke color because /'P22' is an invalid float value
# Cannot set gray stroke color because /'P23' is an invalid float value
# Cannot set gray non-stroke color because /'P23' is an invalid float value
# Cannot set gray stroke color because /'P26' is an invalid float value
# Cannot set gray non-stroke color because /'P26' is an invalid float value
# Cannot set gray stroke color because /'P27' is an invalid float value
# Cannot set gray non-stroke color because /'P27' is an invalid float value
# Cannot set gray stroke color because /'P28' is an invalid float value
# Cannot set gray non-stroke color because /'P28' is an invalid float value
# Cannot set gray stroke color because /'P29' is an invalid float value
# Cannot set gray non-stroke color because /'P29' is an invalid float value
# Cannot set gray stroke color because /'P30' is an invalid float value
# Cannot set gray non-stroke color because /'P30' is an invalid float value
# Cannot set gray stroke color because /'P32' is an invalid float value
# Cannot set gray non-stroke color because /'P32' is an invalid float value
# Cannot set gray stroke color because /'P33' is an invalid float value
# Cannot set gray non-stroke color because /'P33' is an invalid float value
# Cannot set gray stroke color because /'P34' is an invalid float value
# Cannot set gray non-stroke color because /'P34' is an invalid float value
# Cannot set gray stroke color because /'P35' is an invalid float value
# Cannot set gray non-stroke color because /'P35' is an invalid float value
# Cannot set gray stroke color because /'P36' is an invalid float value
# Cannot set gray non-stroke color because /'P36' is an invalid float value
# Cannot set gray stroke color because /'P37' is an invalid float value
# Cannot set gray non-stroke color because /'P37' is an invalid float value
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
#  33%|███▎      | 150/459 [25:05<31:42,  6.16s/it]Cannot set gray non-stroke color because /'P36' is an invalid float value
# Cannot set gray non-stroke color because /'P44' is an invalid float value
#  33%|███▎      | 152/459 [25:36<54:19, 10.62s/it]Cannot set gray non-stroke color because /'p7' is an invalid float value
# Cannot set gray non-stroke color because /'p8' is an invalid float value
# Cannot set gray non-stroke color because /'p9' is an invalid float value
# Cannot set gray non-stroke color because /'p10' is an invalid float value
# Cannot set gray non-stroke color because /'p11' is an invalid float value
# Cannot set gray non-stroke color because /'p12' is an invalid float value
#  33%|███▎      | 153/459 [25:49<57:07, 11.20s/it]Cannot set gray non-stroke color because /'P20' is an invalid float value
# Cannot set gray non-stroke color because /'P28' is an invalid float value
# Cannot set gray non-stroke color because /'P44' is an invalid float value
# Cannot set gray non-stroke color because /'P50' is an invalid float value
#  34%|███▍      | 155/459 [25:59<40:40,  8.03s/it]Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
#  36%|███▋      | 167/459 [27:14<29:12,  6.00s/it]Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
# Cannot set gray non-stroke color because /'P4' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
# Cannot set gray non-stroke color because /'P6' is an invalid float value
#  41%|████      | 187/459 [30:49<46:26, 10.25s/it]  Cannot set gray non-stroke color because /'P11' is an invalid float value
# Cannot set gray non-stroke color because /'P20' is an invalid float value
# Cannot set gray non-stroke color because /'P26' is an invalid float value
# Cannot set gray non-stroke color because /'P32' is an invalid float value
# Cannot set gray non-stroke color because /'P38' is an invalid float value
#  41%|████      | 189/459 [31:01<35:03,  7.79s/it]Cannot set gray non-stroke color because /'P55' is an invalid float value
#  43%|████▎     | 196/459 [33:06<1:27:11, 19.89s/it]Cannot set gray non-stroke color because /'PT20' is an invalid float value
# Cannot set gray non-stroke color because /'PT20' is an invalid float value
# Cannot set gray non-stroke color because /'PT22' is an invalid float value
# Cannot set gray non-stroke color because /'PT20' is an invalid float value
# Cannot set gray non-stroke color because /'PT22' is an invalid float value
#  43%|████▎     | 198/459 [33:31<1:09:31, 15.98s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
#  44%|████▍     | 201/459 [33:56<50:59, 11.86s/it]  Cannot set gray non-stroke color because /'Paint1' is an invalid float value
# Cannot set gray non-stroke color because /'Paint2' is an invalid float value
#  45%|████▌     | 207/459 [34:54<45:37, 10.86s/it]Cannot set gray non-stroke color because /'P23' is an invalid float value
# Cannot set gray non-stroke color because /'P31' is an invalid float value
# Cannot set gray non-stroke color because /'P39' is an invalid float value
#  48%|████▊     | 219/459 [36:38<44:24, 11.10s/it]Cannot set gray non-stroke color because /'P11' is an invalid float value
#  49%|████▉     | 224/459 [37:22<41:05, 10.49s/it]Cannot set gray non-stroke color because /'P9' is an invalid float value
# Cannot set gray non-stroke color because /'P11' is an invalid float value
# Cannot set gray non-stroke color because /'P13' is an invalid float value
# Cannot set gray non-stroke color because /'P15' is an invalid float value
# Cannot set gray non-stroke color because /'P17' is an invalid float value
# Cannot set gray non-stroke color because /'P19' is an invalid float value
# Cannot set gray non-stroke color because /'P21' is an invalid float value
# Cannot set gray non-stroke color because /'P31' is an invalid float value
# Cannot set gray non-stroke color because /'P33' is an invalid float value
# Cannot set gray non-stroke color because /'P35' is an invalid float value
# Cannot set gray non-stroke color because /'P37' is an invalid float value
# Cannot set gray non-stroke color because /'P39' is an invalid float value
# Cannot set gray non-stroke color because /'P41' is an invalid float value
# Cannot set gray non-stroke color because /'P43' is an invalid float value
# Cannot set gray non-stroke color because /'P46' is an invalid float value
# Cannot set gray non-stroke color because /'P48' is an invalid float value
# Cannot set gray non-stroke color because /'P50' is an invalid float value
# Cannot set gray non-stroke color because /'P52' is an invalid float value
# Cannot set gray non-stroke color because /'P54' is an invalid float value
# Cannot set gray non-stroke color because /'P56' is an invalid float value
# Cannot set gray non-stroke color because /'P58' is an invalid float value
# ...
#  93%|█████████▎| 427/459 [1:38:26<07:29, 14.05s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H6' is an invalid float value
# Cannot set gray non-stroke color because /'H7' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H8' is an invalid float value
# Cannot set gray non-stroke color because /'H8' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H9' is an invalid float value
#  96%|█████████▋| 442/459 [1:40:11<01:52,  6.59s/it]Cannot set gray non-stroke color because /'P0' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
# Cannot set gray non-stroke color because /'P0' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P2' is an invalid float value
# Cannot set gray non-stroke color because /'P3' is an invalid float value
# Cannot set gray non-stroke color because /'P4' is an invalid float value
# Cannot set gray non-stroke color because /'P5' is an invalid float value
#  98%|█████████▊| 449/459 [1:41:13<01:25,  8.52s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
#  99%|█████████▊| 453/459 [1:41:53<00:56,  9.36s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H5' is an invalid float value
#  99%|█████████▉| 455/459 [1:42:04<00:28,  7.19s/it]Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H1' is an invalid float value
# Cannot set gray non-stroke color because /'H2' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# Cannot set gray non-stroke color because /'H3' is an invalid float value
# Cannot set gray non-stroke color because /'H4' is an invalid float value
# 100%|██████████| 459/459 [1:42:38<00:00, 13.42s/it]
# Metadata saved to 'NeurIPS2024_Datasets_and_Benchmarks/metadata.csv'
# Done

# %%
import pandas as pd
df = pd.read_csv('NeurIPS2024_Datasets_and_Benchmarks/metadata.csv')
df.head()
# Out:
#                                                title  \
# 0  DevBench: A multimodal developmental benchmark...
# 1  Point Cloud Matters: Rethinking the Impact of ...
# 2  XLand-MiniGrid: Scalable Meta-Reinforcement Le...
# 3  kGym: A Platform and Dataset to Benchmark Larg...
# 4  $E^3$: Exploring Embodied Emotion Through A La...
#
#                                             keywords  \
# 0  ['multimodal', 'developmental', 'language', 'e...
# 1  ['Point Cloud', 'RGB-D images', 'Robot Learnin...
# 2  ['reinforcement learning', 'meta-reinforcement...
# 3  ['Benchmarks', 'Datasets', 'Natural Language P...
# 4  ['emotion analysis; egocentric datasets ; vide...
#
#                                openreview_url  \
# 0  https://openreview.net/forum?id=zogaeVpbaE
# 1  https://openreview.net/forum?id=zgSnSZ0Re6
# 2  https://openreview.net/forum?id=zg8dpAGl1I
# 3  https://openreview.net/forum?id=zQ3qU0xWZ5
# 4  https://openreview.net/forum?id=zGfKPqunJG
#
#                                         pdf_filename  \
# 0  DevBench_A_multimodal_developmental_benchmark_...
# 1  Point_Cloud_Matters_Rethinking_the_Impact_of_D...
# 2  XLand-MiniGrid_Scalable_Meta-Reinforcement_Lea...
# 3  kGym_A_Platform_and_Dataset_to_Benchmark_Large...
# 4  $E^3$_Exploring_Embodied_Emotion_Through_A_Lar...
#
#                                             fulltext
# 0  DEVBENCH: A multimodal developmental benchmark...
# 1  Point Cloud Matters: Rethinking the Impact of\...
# 2  XLand-MiniGrid: Scalable Meta-Reinforcement\nL...
# 3  KGYM: A Platform and Dataset to Benchmark Larg...
# 4  E3\n: Exploring Embodied Emotion Through\nA La...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           459 non-null    object
#  1   keywords        459 non-null    object
#  2   openreview_url  459 non-null    object
#  3   pdf_filename    459 non-null    object
#  4   fulltext        459 non-null    object
# dtypes: object(5)
# memory usage: 18.1+ KB

# %%
# checking for failed fulltext extractions
empty_mask = df['fulltext'].fillna('').str.strip() == ''
missing_fulltext = df.loc[empty_mask, ['title', 'pdf_filename']]

if missing_fulltext.empty:
    print("No failed fulltext extractions")
else:
    print("Failed fulltext extractions:")
    print(missing_fulltext)
# Out:
# Failed fulltext extractions:
#                                                  title  \
# 180  LINGOLY: A Benchmark of Olympiad-Level Linguis...
#
#                                           pdf_filename
# 180  LINGOLY_A_Benchmark_of_Olympiad-Level_Linguist...

# %%
"""
# The failed fulltext extraction seems to be image-based. Will use tesseract to extract text instead.
# I will manually input the fulltext into the .csv file, since it is only one article.
import pytesseract
from pdf2image import convert_from_path
import os

def extract_text_from_image_pdf(pdf_path):
    try:
        images = convert_from_path(pdf_path)
        full_text = ""
        for i, image in enumerate(images):
            print(f"   - Reading page {i + 1}/{len(images)}")
            text = pytesseract.image_to_string(image)
            full_text += text + "\n\n" # Add page breaks

        print(full_text)

    except Exception as e:
        print(f"An error occurred during OCR processing: {e}")
        print("Please ensure Tesseract is installed and accessible in your system's PATH.")


if __name__ == "__main__":
    filename = "LINGOLY_A_Benchmark_of_Olympiad-Level_Linguistic_Reasoning_Puzzles_in_Low_Resource_and_Extinct_Languages.pdf"
    folder = "NeurIPS2024_Datasets_and_Benchmarks"
    file_to_process = os.path.join(folder, filename)

    extract_text_from_image_pdf(file_to_process)
"""
# Out:
# '\n# The failed fulltext extraction seems to be image-based. Will use tesseract to extract text instead.\n# I will manually input the fulltext into the .csv file, since it is only one article.\nimport pytesseract\nfrom pdf2image import convert_from_path\nimport os\n\ndef extract_text_from_image_pdf(pdf_path):\n    try:\n        images = convert_from_path(pdf_path)\n        full_text = ""\n        for i, image in enumerate(images):\n            print(f"   - Reading page {i + 1}/{len(images)}")\n            text = pytesseract.image_to_string(image)\n            full_text += text + "\n\n" # Add page breaks\n\n        print(full_text)\n\n    except Exception as e:\n        print(f"An error occurred during OCR processing: {e}")\n        print("Please ensure Tesseract is installed and accessible in your system\'s PATH.")\n\n\nif __name__ == "__main__":\n    filename = "LINGOLY_A_Benchmark_of_Olympiad-Level_Linguistic_Reasoning_Puzzles_in_Low_Resource_and_Extinct_Languages.pdf"\n    folder = "NeurIPS2024_Datasets_and_Benchmarks"\n    file_to_process = os.path.join(folder, filename)\n\n    extract_text_from_image_pdf(file_to_process)\n'

# %%
#removing the row where the fulltext is empty
df.to_csv('NeurIPS2024_Datasets_and_Benchmarks/backup_metadata.csv', index=False)

# %%
row = df.iloc[180]
print(row['title'])
df.info()
# Out:
# LINGOLY: A Benchmark of Olympiad-Level Linguistic Reasoning Puzzles in Low Resource and Extinct Languages
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           459 non-null    object
#  1   keywords        459 non-null    object
#  2   openreview_url  459 non-null    object
#  3   pdf_filename    459 non-null    object
#  4   fulltext        459 non-null    object
# dtypes: object(5)
# memory usage: 18.1+ KB

# %%
# SIKRE AT DET ER DET RIGTIGE INDEx!!!!
df = df.drop(df.index[180])

# %%
row = df.iloc[180]
print(row['title'])
df.info()
# Out:
# WebUOT-1M: Advancing Deep Underwater Object Tracking with A Million-Scale Benchmark
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           458 non-null    object
#  1   keywords        458 non-null    object
#  2   openreview_url  458 non-null    object
#  3   pdf_filename    458 non-null    object
#  4   fulltext        458 non-null    object
# dtypes: object(5)
# memory usage: 21.5+ KB

# %%
def add_word_column():
    file_path = os.path.join('NeurIPS2024_Datasets_and_Benchmarks', 'metadata.csv')

    search_terms = {
        'representation_mentioned': r'represent',
        'diversity_mentioned': r'divers',
        'similarity_mentioned': r'similar',
    }

    try:
        print(f"Reading file: {file_path}")
        df = pd.read_csv(file_path)

        for column_name, pattern in search_terms.items():
            df[column_name] = df['fulltext'].str.contains(
                pattern,
                case=False,
                regex=True
            ).astype(int)

        df.to_csv(file_path, index=False)

        #checking the results
        print(df[['title'] + list(search_terms.keys())].head())

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    add_word_column()
# Out:
# Reading file: NeurIPS2024_Datasets_and_Benchmarks/metadata.csv
#                                                title  \
# 0  DevBench: A multimodal developmental benchmark...
# 1  Point Cloud Matters: Rethinking the Impact of ...
# 2  XLand-MiniGrid: Scalable Meta-Reinforcement Le...
# 3  kGym: A Platform and Dataset to Benchmark Larg...
# 4  $E^3$: Exploring Embodied Emotion Through A La...
#
#    representation_mentioned  diversity_mentioned  similarity_mentioned
# 0                         1                    1                     1
# 1                         1                    1                     1
# 2                         1                    1                     1
# 3                         1                    1                     1
# 4                         1                    1                     0

# %%
df2 = pd.read_csv('NeurIPS2024_Datasets_and_Benchmarks/metadata.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     459 non-null    object
#  1   keywords                  459 non-null    object
#  2   openreview_url            459 non-null    object
#  3   pdf_filename              459 non-null    object
#  4   fulltext                  459 non-null    object
#  5   representation_mentioned  459 non-null    int64
#  6   diversity_mentioned       459 non-null    int64
#  7   similarity_mentioned      459 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 28.8+ KB

# %%
#checking how many articles contain each of the three words and their frequency
word_columns = ['representation_mentioned', 'diversity_mentioned', 'similarity_mentioned']
total_articles = len(df2)

for col in word_columns:
    count = df2[col].sum()
    percentage = (count / total_articles) * 100
    print(f"Number of articles containing '{col}': {count}")
    print(f"Percentage of articles containing '{col}': {percentage:.2f}%")

combination_counts = df2.groupby(word_columns).size().reset_index(name='article_count')
combination_counts = combination_counts.sort_values(by='article_count', ascending=False)

print("Combination of word mentions (1=mentioned, 0=not mentioned):")
print(combination_counts.to_string(index=False))
# Out:
# Number of articles containing 'representation_mentioned': 452
# Percentage of articles containing 'representation_mentioned': 98.47%
# Number of articles containing 'diversity_mentioned': 428
# Percentage of articles containing 'diversity_mentioned': 93.25%
# Number of articles containing 'similarity_mentioned': 436
# Percentage of articles containing 'similarity_mentioned': 94.99%
# Combination of word mentions (1=mentioned, 0=not mentioned):
#  representation_mentioned  diversity_mentioned  similarity_mentioned  article_count
#                         1                    1                     1            407
#                         1                    0                     1             24
#                         1                    1                     0             17
#                         1                    0                     0              4
#                         0                    1                     1              3
#                         0                    0                     1              2
#                         0                    0                     0              1
#                         0                    1                     0              1

# %%
#checking the frequency of different keywords from article metadata
from collections import Counter

cleaned_keywords = (
    df2['keywords']
    .str.lower()  #lowercase
    .str.replace(r"[\[\]']", "", regex=True)  #remove brackets and quotes
    .str.split(',')
    .explode()
    .str.strip()  #remove leading/trailing whitespace
)

#counting frequencies
keyword_counts = cleaned_keywords.value_counts()
keyword_counts = keyword_counts[keyword_counts.index != '']
print("keyword frequencies:")
print(keyword_counts.head(20))
# Out:
# keyword frequencies:
# benchmark                           88
# large language models               40
# dataset                             40
# evaluation                          20
# large language model                16
# reinforcement learning              15
# llms                                15
# multimodal                          14
# llm                                 13
# benchmarks                          12
# computer vision                     12
# machine learning                    10
# vision-language models               9
# remote sensing                       8
# datasets                             8
# benchmarking                         8
# multimodal large language models     7
# synthetic data                       7
# graph neural networks                7
# healthcare                           6
# Name: keywords, dtype: int64

# %%
#TODO
#FINISH ARTICLE CODING/ANNOTATION
#ADD COLUMN WITH PARAGRAPHS WHERE WORDS ARE MENTIONED
#WRITE ARTICLE :))
